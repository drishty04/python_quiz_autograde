# %% [markdown]
# # 🧩 Python Quiz 1 — Local Version
# Fill your ID and answers, then run the grading cell at the end to see your score.

# %%
STUDENT_ID = 'Enter your ID here'
STUDENT_NAME = 'Your Name'

# %% [markdown]
# ### Q1. Write a function to return the square of a number.

# %%
def square(x):
    pass

# %% [markdown]
# ### Q2. What is the output of `type([])`?

# %%
answer_q2 = ''

# %%
score = 0
total = 2
feedback = {}
try:
    if callable(square) and square(3) == 9:
        score += 1
        feedback['Q1'] = '✅ Correct'
    else:
        feedback['Q1'] = '❌ Incorrect'
except Exception as e:
    feedback['Q1'] = f'❌ Error: {e}'
if 'list' in answer_q2.lower():
    score += 1
    feedback['Q2'] = '✅ Correct'
else:
    feedback['Q2'] = '❌ Expected list'
print(f'Score: {score}/{total} ({(score/total)*100:.1f}%)')
for k,v in feedback.items():
    print(f'{k}: {v}')
