# %% [markdown]
# # 🧠 Python Quiz 1
# **Instructions:**
# 1. Fill your STUDENT_ID and STUDENT_NAME below.
# 2. Answer all questions.
# 3. Save and submit via GitHub Pull Request.

# %%
STUDENT_ID = 'Enter your ID here'
STUDENT_NAME = 'Your Name'

# %% [markdown]
# ### Q1. Write a function `square(x)` that returns the square of x.

# %%
def square(x):
    pass

# %% [markdown]
# ### Q2. What is the output of `type([])`?

# %%
answer_q2 = ''
